# %% [markdown]
# ### oracle 서버와 파이썬 연동

# %%
import oracledb
from dotenv import load_dotenv 
import os

# %%
# .env 파일 읽어오기
load_dotenv()

# 오라클 비밀번호 가져오기
password =  os.getenv('oracle_password')

# %%
conn = oracledb.connect(user = 'python_user', password = '2394', dsn = 'localhost/xe')
cursor = conn.cursor()

cursor.execute('select * from post')

for row in cursor.fetchall():
    print(row)

conn.close()

# %%
sql = 'insert into hanbit_member(member_id,name,password) values(:1,:2,:3)'
# sql = 'insert into hanbit_memeber(member_id,name,password) values(:member_id,:name,:password)'

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql, ('hong123', '홍길동', 'hong123'))
        conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[14], line 6
#       4 with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
#       5     with conn.cursor() as cursor:
# ----> 6         cursor.execute(sql, ('hong123', '홍길동', 'hong123'))
#       7         conn.commit()
#
# File c:\Users\Nopen\Desktop\LLTTYY\soldesk\source\pythonsource\.venv\lib\site-packages\oracledb\cursor.py:859, in Cursor.execute(self, statement, parameters, suspend_on_success, fetch_lobs, fetch_decimals, **keyword_parameters)
#     857     impl.fetch_decimals = fetch_decimals
#     858 impl.suspend_on_success = suspend_on_success
# --> 859 impl.execute(self)
#     860 if impl.fetch_vars is not None:
#     861     return self
#
# File src/oracledb/impl/thin/cursor.pyx:279, in oracledb.thin_impl.ThinCursorImpl.execute()
#
# File src/oracledb/impl/thin/protocol.pyx:501, in oracledb.thin_impl.Protocol._process_single_message()
#
# File src/oracledb/impl/thin/protocol.pyx:502, in oracledb.thin_impl.Protocol._process_single_message()
#
# File src/oracledb/impl/thin/protocol.pyx:494, in oracledb.thin_impl.Protocol._process_message()
#
# File src/oracledb/impl/thin/messages/base.pyx:102, in oracledb.thin_impl.Message._check_and_raise_exception()
#
# IntegrityError: ORA-00001: 무결성 제약 조건(PYTHON_USER.PK_HABIT_MEMBER)에 위배됩니다
# Help: https://docs.oracle.com/error-help/db/ora-00001/

# %%
with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        cursor.execute('select * from hanbit_member')

        for row in cursor.fetchall():
            print(row)
# Out:
# ('hong123', 'hong123', '홍길동', None, 'REGULAR', 0)

# %%
sql = 'insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)'

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        data = {
            'member_id' : 'choi123',
            'name' : '조미연',
            'password' : 'choi123'}

        cursor.execute(sql, data)
        conn.commit()

# %%
""" db에 카테고리 없음
sql = 'insert into category(category_id, category_name) values(:1,:2)'

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql, (1101, '경제/경영'))
        conn.commit()
"""

# %%
""" db에 카테고리 없음
sql = 'insert into category(category_id, category_name) values(:1,:2)'
data = [
    [1102, '요리']
    [1103, '예술']
    [1104, '사회']
]

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        

        cursor.execute(sql, (1101, data))
        conn.commit()
"""

# %%
""" db에 카테고리 없음
sql = 'update category set category_name =:1 where category_id = :2'

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql, (1101, '경제/경영'))
        conn.commit()
"""

# %%
from faker import Faker

fake = Faker(locale = 'ko_KR')
Faker.seed(4321)

print(fake.name())
print(fake.email())
print(fake.address())
print(fake.ssn())
print(fake.phone_number())
# Out:
# 이도윤
# sunoggim@example.net
# 대구광역시 영등포구 서초중앙거리 238-52
# 670227-2018273
# 070-4938-5639

# %%
from faker.providers import internet

fake.add_provider(internet)

for i in range(10):
    print(fake.ipv4_private())
# Out:
# 192.168.107.240
# 192.168.112.114
# 192.168.151.178
# 10.179.78.168
# 172.18.48.9
# 172.22.63.107
# 10.33.13.83
# 192.168.231.224
# 192.168.222.129
# 10.247.26.50

# %%
fake.date_of_birth(minimum_age=20,maximum_age=30)
fake.date_of_birth(minimum_age=20,maximum_age=30).strftime('%Y-%m-%d')
# Out:
# '1997-03-05'

# %%
fake.date_time_between(start_date='-3y', end_date='now')
# Out:
# datetime.datetime(2026, 4, 20, 0, 48, 55)

# %%
# maru_member 50명의 임의의 데이터를 이용해 삽임
# name, birth, phone, joined_at
data = []

fake = Faker(locale = 'ko_KR')
Faker.seed(2222+i)

for _ in range(50):
    name = fake.name()
    birth = fake.date_of_birth(minimum_age=20,maximum_age=70).strftime('%Y-%m-%d')
    phone = fake.phone_number()
    joined_at = fake.date_time_between(start_date='-2y', end_date='now')

    # 50명이 데이터를 리스트에 추가 
    data.append([name, birth, phone, joined_at])

    
print(data)
# Out:
# [['노도윤', '1975-08-24', '017-778-1240', datetime.datetime(2025, 10, 8, 1, 56, 18)], ['장동현', '1964-02-12', '055-661-8255', datetime.datetime(2026, 7, 3, 1, 4, 26)], ['윤도윤', '1956-09-01', '054-058-0015', datetime.datetime(2026, 1, 16, 19, 0, 26)], ['김미경', '1965-09-05', '044-841-9530', datetime.datetime(2025, 5, 23, 1, 50, 43)], ['홍현숙', '1962-05-02', '011-620-8212', datetime.datetime(2024, 12, 1, 8, 21, 32)], ['김지은', '1971-12-24', '033-997-7917', datetime.datetime(2025, 1, 10, 12, 6, 41)], ['송영미', '1983-06-26', '042-750-7425', datetime.datetime(2025, 3, 18, 0, 59, 11)], ['윤하은', '1993-09-08', '032-141-4323', datetime.datetime(2026, 8, 3, 19, 2, 25)], ['김지현', '1958-08-22', '031-606-7018', datetime.datetime(2025, 5, 26, 0, 14, 3)], ['윤미영', '2001-08-05', '011-448-6117', datetime.datetime(2025, 4, 21, 6, 39, 33)], ['신지민', '1958-07-03', '052-801-9361', datetime.datetime(2026, 2, 9, 13, 42, 40)], ['권현우', '1966-02-28', '063-207-8998', datetime.datetime(2025, 4, 20, 11, 31, 10)], ['양지아', '1990-03-25', '055-738-9725', datetime.datetime(2025, 3, 20, 15, 43, 13)], ['김영희', '1968-12-22', '070-9464-6366', datetime.datetime(2024, 12, 1, 18, 27, 38)], ['김상현', '1986-09-14', '062-928-0757', datetime.datetime(2025, 7, 22, 21, 10, 46)], ['우현정', '1955-11-10', '016-510-6121', datetime.datetime(2025, 8, 6, 21, 1, 45)], ['한지원', '1986-07-19', '042-559-9882', datetime.datetime(2025, 11, 2, 1, 47, 29)], ['김은경', '2000-12-08', '043-861-0158', datetime.datetime(2025, 12, 3, 4, 55, 13)], ['박건우', '1991-04-05', '032-748-4925', datetime.datetime(2026, 5, 14, 21, 17, 44)], ['김채원', '1967-06-18', '042-023-3629', datetime.datetime(2025, 9, 17, 2, 14, 1)], ['박정희', '1961-05-13', '032-133-0817', datetime.datetime(2026, 7, 26, 13, 11, 26)], ['김미영', '1977-01-26', '02-3377-6047', datetime.datetime(2026, 4, 3, 14, 27, 41)], ['이유진', '1993-09-27', '018-368-4762', datetime.datetime(2025, 2, 10, 4, 4, 42)], ['김건우', '2001-05-27', '041-629-6952', datetime.datetime(2026, 3, 15, 9, 47, 57)], ['이성수', '2005-10-21', '064-791-6601', datetime.datetime(2024, 10, 21, 21, 19, 21)], ['오지원', '1986-04-24', '011-167-6914', datetime.datetime(2025, 5, 17, 14, 56, 34)], ['류현준', '1990-02-09', '016-917-4620', datetime.datetime(2025, 3, 9, 13, 15, 39)], ['김현지', '2005-11-02', '043-429-6682', datetime.datetime(2026, 5, 22, 6, 54, 22)], ['이상현', '1959-06-21', '018-740-1220', datetime.datetime(2025, 9, 2, 9, 29, 22)], ['김광수', '1960-11-20', '041-222-4768', datetime.datetime(2025, 8, 18, 14, 27, 44)], ['최명숙', '1980-10-30', '063-987-0329', datetime.datetime(2025, 8, 13, 4, 16, 27)], ['이지원', '1986-01-26', '043-913-1793', datetime.datetime(2025, 6, 12, 11, 17, 53)], ['이정자', '1976-05-26', '042-844-1417', datetime.datetime(2026, 5, 12, 13, 2, 49)], ['김영환', '1963-12-08', '063-640-8293', datetime.datetime(2025, 9, 18, 1, 13, 27)], ['김상철', '2002-01-14', '011-386-9047', datetime.datetime(2025, 3, 17, 22, 56, 56)], ['권현준', '1980-10-05', '063-061-9692', datetime.datetime(2025, 5, 22, 5, 3, 43)], ['안상철', '1983-07-25', '064-742-5593', datetime.datetime(2025, 5, 5, 19, 46, 43)], ['박현우', '1959-08-25', '055-176-7890', datetime.datetime(2025, 2, 13, 12, 50, 52)], ['이민수', '1959-03-01', '018-738-2422', datetime.datetime(2026, 1, 13, 8, 30, 38)], ['김지현', '1968-04-30', '042-079-4987', datetime.datetime(2025, 4, 5, 18, 55, 58)], ['우정훈', '1991-03-04', '042-596-2280', datetime.datetime(2026, 4, 23, 22, 5, 3)], ['송진우', '1986-08-12', '033-020-2423', datetime.datetime(2024, 11, 18, 15, 56, 30)], ['하아름', '1986-06-30', '061-275-3018', datetime.datetime(2024, 10, 3, 16, 56, 54)], ['김성수', '1974-05-29', '051-514-9068', datetime.datetime(2024, 9, 7, 17, 49, 31)], ['서영숙', '1994-11-09', '051-125-7139', datetime.datetime(2024, 9, 9, 21, 40, 5)], ['김정식', '1997-05-15', '063-093-3961', datetime.datetime(2024, 8, 27, 23, 7, 52)], ['강재호', '1961-09-08', '053-485-5000', datetime.datetime(2025, 7, 7, 14, 40, 18)], ['최건우', '1965-09-27', '052-270-5095', datetime.datetime(2026, 6, 30, 4, 26, 11)], ['김은서', '1975-07-06', '061-892-5298', datetime.datetime(2 ...

# %%
# insert
sql = 'insert into maru_memer(name,birth, phone, joined_at) values(:1,:2,:3,:4)'

with oracledb.connect(user = 'python_user', password = password, dsn = 'localhost/xe')as conn:
    with conn.cursor() as cursor:
        cursor.executemany(sql, data)
        conn.commit()
